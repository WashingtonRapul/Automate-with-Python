# %% [markdown]
# <a href="https://colab.research.google.com/github/WashingtonRapul/Automate-with-Python/blob/main/Extract%20CSV%20Files%20from%20Websites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Read a .csv from a URL with Pandas
#
# Targe website: https://www.football-data.co.uk/data.php

# %%
import pandas as pd

# %%
#reading 1 csv file from the website
df_premier22 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv')

# %%
#showing dataframe
df_premier22
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 375  E0  28/05/2023  16:30         Everton    Bournemouth     1     0   H
# 376  E0  28/05/2023  16:30           Leeds      Tottenham     1     4   A
# 377  E0  28/05/2023  16:30       Leicester       West Ham     2     1   H
# 378  E0  28/05/2023  16:30      Man United         Fulham     2     1   H
# 379  E0  28/05/2023  16:30     Southampton      Liverpool     4     4   D
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
#rename columns
df_premier22.rename(columns ={'FTHG':'home_goals',
                              'FTAG':'away_goals'}, inplace = True),
# Out:
# (None,)

# %%
#show dataframe
df_premier22
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  home_goals  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal           0
# 1    E0  06/08/2022  12:30          Fulham      Liverpool           2
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa           2
# 3    E0  06/08/2022  15:00           Leeds         Wolves           2
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest           2
# ..   ..         ...    ...             ...            ...         ...
# 375  E0  28/05/2023  16:30         Everton    Bournemouth           1
# 376  E0  28/05/2023  16:30           Leeds      Tottenham           1
# 377  E0  28/05/2023  16:30       Leicester       West Ham           2
# 378  E0  28/05/2023  16:30      Man United         Fulham           2
# 379  E0  28/05/2023  16:30     Southampton      Liverpool           4
#
#      away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...
